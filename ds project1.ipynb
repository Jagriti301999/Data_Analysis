# %% [markdown]
# # DATA ANALYSIS USING PYTHON

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\91938\\Desktop\\scriptsLecture\\section6\\happy2015.csv")#add r then no error

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
data.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.relplot(x="Family", y="Region",hue="Economy (GDP per Capita)",data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="Country", y="Economy (GDP per Capita)",kind="line",data=data)

# %%
data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
sns.catplot(x="Economy (GDP per Capita)",y="Health (Life Expectancy)",data=data)#use to show graph on categorical data

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from sklearn .preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv(r"C:\Users\91938\Desktop\scriptsLecture\section10\glassClass.csv")

# %%
data.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
data.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516523   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
mag=LabelEncoder()
data['Mg']=mag.fit_transform(data['Mg'])

# %%
data.head()
# Out:
#         RI     Na  Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  93  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  62  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  57  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  71  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  64  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
bins=(0.5,0.9,0.99,1.0)
type=['metals','non-metals','metalloids']
data['Na']=pd.cut(data['Na'],bins=bins,labels=type)

# %%
data['Na']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
#       ...
# 184    NaN
# 185    NaN
# 186    NaN
# 187    NaN
# 188    NaN
# 189    NaN
# 190    NaN
# 191    NaN
# 192    NaN
# 193    NaN
# 194    NaN
# 195    NaN
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200    NaN
# 201    NaN
# 202    NaN
# 203    NaN
# 204    NaN
# 205    NaN
# 206    NaN
# 207    NaN
# 208    NaN
# 209    NaN
# 210    NaN
# 211    NaN
# 212    NaN
# 213    NaN
# Name: Na, Length: 214, dtype: category
# Categories (3, object): [metals < non-metals < metalloids]

# %%
data['Type'].value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type, dtype: int64

# %%
sns.countplot(data['Mg'])

# %%
sns.relplot(x="K",y="Na",hue="Type",kind='line',data=data,height=1,aspect=3)

# %%
x=data.drop('K',axis=1)
y=data['Na']

# %%
x_train , x_test , y_train , y_test=train_test_split(x,y,test_size=0.5,random_state=0)

# %%
s=StandardScaler()
X_train=s.fit_transform(x_train)
X_test=s.transform(x_test)
# Out:
# C:\Users\91938\Anaconda3\lib\site-packages\sklearn\utils\extmath.py:747: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\91938\Anaconda3\lib\site-packages\sklearn\utils\extmath.py:688: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = op(x, *args, **kwargs)

# %% [markdown]
# # credit card fraud detection

# %% [markdown]
# import pandas as pd
# import numpy as np
# import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\91938\\Downloads\\creditcard.zip")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
fraud=data.loc[data['Class']==1]

# %%
normal=data.loc[data['Class']==0]

# %%
fraud
# Out:
#             Time        V1        V2         V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992  -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307   1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247  -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367  -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740  -4.304597  4.732795  3.624201 -1.357746
# 6331      7526.0  0.008430  4.137837  -6.240697  6.675732  0.768307 -3.353060
# 6334      7535.0  0.026779  4.132464  -6.560600  6.348557  1.329666 -2.513479
# 6336      7543.0  0.329594  3.712889  -5.775935  6.078266  1.667359 -2.420168
# 6338      7551.0  0.316459  3.809076  -5.615159  6.047445  1.554026 -2.651353
# 6427      7610.0  0.725646  2.300894  -5.329976  4.007683 -1.730411 -1.732193
# 6446      7672.0  0.702710  2.426433  -5.234513  4.416661 -2.170806 -2.667554
# ...

# %%
fraud.sum()
# Out:
# Time      3.972743e+07
# V1       -2.347799e+03
# V2        1.782899e+03
# V3       -3.460374e+03
# V4        2.234678e+03
# V5       -1.550403e+03
# V6       -6.876865e+02
# V7       -2.739816e+03
# V8        2.807529e+02
# V9       -1.269912e+03
# V10      -2.793026e+03
# V11       1.869685e+03
# V12      -3.079621e+03
# V13      -5.379224e+01
# V14      -3.430088e+03
# V15      -4.572094e+01
# V16      -2.036853e+03
# V17      -3.279592e+03
# V18      -1.105184e+03
# V19       3.348844e+02
# V20       1.831811e+02
# V21       3.510855e+02
# V22       6.912050e+00
# V23      -1.983152e+01
# V24      -5.172411e+01
# V25       2.039285e+01
# V26       2.541088e+01
# V27       8.392280e+01
# V28       3.722831e+01
# Amount    6.012797e+04
# Class     4.920000e+02
# dtype: float64

# %%
len(fraud)
# Out:
# 492

# %%
len(normal)
# Out:
# 284315

# %%
sns.relplot(x="Amount",y="Time",hue="Class",data=data)

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
x=data.iloc[:,:-1]
y=data['Class']

# %%
x_train , x_test , y_train , y_test=train_test_split(x,y,test_size=0.35)

# %%
clf=linear_model.LogisticRegression(C=1e5)

# %%
clf.fit(x_train,y_train)
# Out:
# C:\Users\91938\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=np.array(clf.predict(x_test))
y=np.array(y_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[99488    22]
#  [   73   100]]

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9990469789231865

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     99510
#            1       0.82      0.58      0.68       173
#
#     accuracy                           1.00     99683
#    macro avg       0.91      0.79      0.84     99683
# weighted avg       1.00      1.00      1.00     99683
